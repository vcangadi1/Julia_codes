# %%
using PyPlot
# Out:
# INFO: Precompiling module MacroTools.
# WARNING: Method definition macroexpand(Module, Any) in module Compat at /home/juser/.julia/v0.5/Compat/src/Compat.jl:1491 overwritten in module MacroTools at /opt/julia_packages/.julia/v0.5/MacroTools/src/utils.jl:64.
# WARNING: Method definition macroexpand(Module, Any) in module Compat at /home/juser/.julia/v0.5/Compat/src/Compat.jl:1491 overwritten in module MacroTools at /opt/julia_packages/.julia/v0.5/MacroTools/src/utils.jl:64.
# INFO: Precompiling module PyCall.
# WARNING: Method definition macroexpand(Module, Any) in module Compat at /home/juser/.julia/v0.5/Compat/src/Compat.jl:1491 overwritten in module MacroTools at /opt/julia_packages/.julia/v0.5/MacroTools/src/utils.jl:64.
# INFO: Precompiling module PyPlot.
# WARNING: Method definition macroexpand(Module, Any) in module Compat at /home/juser/.julia/v0.5/Compat/src/Compat.jl:1491 overwritten in module MacroTools at /opt/julia_packages/.julia/v0.5/MacroTools/src/utils.jl:64.

# %%
y = open(readdlm,"sum25_GaNseries1.txt");

# %%
x = ((1:1024)-indmax(y))*0.05;

# %%
using Requests
# Out:
# INFO: Precompiling module Requests.

# %%
summary(x)
# Out:
# "1024-element FloatRange{Float64}"

# %%
summary(x')
# Out:
# "1×1024 Array{Float64,2}"

# %%
l = (x')';

# %%
summary(y)
# Out:
# "1×1024 Array{Float64,2}"

# %%
S = y';

# %%
plot(l,S)
title("Calibrated EELS spectrum")
xlabel("Energy-loss axis \(eV\)")
ylabel("Counts")
grid("on")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fb94cc05150>)

# %% [raw]
# summary(plt)

# %%
plt
# Out:
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fb94cf39b90>
